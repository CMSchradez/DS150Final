# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("blkjckhands.csv")
df.head(5)
# Out:
#    Unnamed: 0 PlayerNo  card1  card2  card3  card4  card5  sumofcards  \
# 0           0  Player1      7     10      0      0      0          17
# 1           1  Player2     10      9      0      0      0          19
# 2           2  Player3      9      8      0      0      0          17
# 3           3  Player4      2     10      0      5      0          17
# 4           4  Player5     10      2      0      5      0          17
#
#    dealcard1  dealcard2  ...  dealcard4  dealcard5  sumofdeal  blkjck winloss  \
# 0         10          8  ...          0          0         18   nowin    Loss
# 1         10          8  ...          0          0         18   nowin     Win
# 2         10          8  ...          0          0         18   nowin    Loss
# 3         10          8  ...          0          0         18   nowin    Loss
# 4         10          8  ...          0          0         18   nowin    Loss
#
#   plybustbeat dlbustbeat plwinamt  dlwinamt  ply2cardsum
# ...

# %%
# Start of table to variable (state) conversion

# States
"""
PlayerNumber
PlayerSum
DealerSum
WinLoss
DealerBustWin
PlayerBustWin
BlackJack

Possible: Hit / Stand , NumberOfCards , 

"""

PlayerNumber = df["PlayerNo"]
PlayerSum = df["sumofcards"]
DealerSum = df["sumofdeal"]
WinLoss = df["winloss"]
DealerBustWin = df["dlbustbeat"]
PlayerBustWin = df["plybustbeat"]
BlackJack = df["blkjck"]

# These all give a series tbat index up to the 900k, name represents whats happening.

# %%
#print(PlayerNumber)
#print(PlayerSum)
#print(DealerSum)
#print(WinLoss)
#print(DealerBustWin)
#print(PlayerBustWin)
#print(BlackJack)

# %%
df.head(10)
# Out:
#    Unnamed: 0 PlayerNo  card1  card2  card3  card4  card5  sumofcards  \
# 0           0  Player1      7     10      0      0      0          17
# 1           1  Player2     10      9      0      0      0          19
# 2           2  Player3      9      8      0      0      0          17
# 3           3  Player4      2     10      0      5      0          17
# 4           4  Player5     10      2      0      5      0          17
# 5           5  Player6      6      1      8     10      0          25
# 6           0  Player1     10      4      0      0      0          14
# 7           1  Player2      3     10      0      0      0          13
# 8           2  Player3     10      2      0      0      0          12
# 9           3  Player4      9      6      0      0      0          15
#
#    dealcard1  dealcard2  ...  dealcard4  dealcard5  sumofdeal  blkjck winloss  \
# 0         10          8  ...          0          0         18   nowin    Loss
# ...

# %%
PlayerNoWinloss_df = (
    df.groupby(["PlayerNo", "winloss"])
      .size()
      .reset_index(name="count")
)

sns.barplot(
    data = PlayerNoWinloss_df,
    x = "PlayerNo",
    y = "count",
    hue = "winloss"
)
# Out:
# <Axes: xlabel='PlayerNo', ylabel='count'>
